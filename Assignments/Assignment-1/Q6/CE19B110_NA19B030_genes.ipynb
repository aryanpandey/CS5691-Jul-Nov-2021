# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 500)

# %%
data = pd.read_csv('assignmentcounts.csv')
data.head(100)
# Out:
#          Unnamed: 0  GTEX-1117F-0426-SM-5EGHI  GTEX-111CU-2026-SM-5GZZC  \
# 0   ENSG00000260534                         0                         0
# 1   ENSG00000227167                         0                         0
# 2   ENSG00000202382                        12                         3
# 3   ENSG00000179913                         0                         0
# 4   ENSG00000272247                         0                         0
# 5   ENSG00000230690                         0                         0
# 6   ENSG00000240770                         0                         0
# 7   ENSG00000257603                         0                         0
# 8   ENSG00000224881                         0                         0
# 9   ENSG00000167748                         1                         0
# 10  ENSG00000268407                         0                         0
# 11  ENSG00000213693                         0                         0
# ...

# %%
data.shape
# Out:
# (4444, 804)

# %%
plt.figure()
plt.hist(data.iloc[15,1:], bins = 200)
plt.title("Gene: ENSG00000082996")
plt.show()

# %%
plt.figure()
plt.hist(data.iloc[29,1:], bins = 200)
plt.title("Gene: ENSG00000104763")
plt.show()

# %%
plt.figure()
plt.hist(data.iloc[53,1:], bins = 200)
plt.title('Gene: ENSG00000065054')
plt.show()

# %%
plt.figure()
plt.hist(data.iloc[54,1:], bins = 200)
plt.title("Gene: ENSG00000138834")
plt.show()
